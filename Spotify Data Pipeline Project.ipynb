# %%
# !pip install spotipy

# %%
# !pip install pandas

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
client_credentials_manager = SpotifyClientCredentials(client_id='b69a8d2f525f4a46a217bc73c58472b7', client_secret='a325a5c529af4919b4d2f6f1668c4360') # used for authentication

# %%
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager) # used for authorization

# %%
playlists = sp.user_playlists('spotify')

# %%
playlists
# Out:
# {'href': 'https://api.spotify.com/v1/users/spotify/playlists?offset=0&limit=50',
#  'limit': 50,
#  'next': 'https://api.spotify.com/v1/users/spotify/playlists?offset=50&limit=50',
#  'offset': 0,
#  'previous': None,
#  'total': 1519,
#  'items': [{'collaborative': False,
#    'description': 'Hozier is on top of the Hottest 50!',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXcBWIGoYBM5M'},
#    'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXcBWIGoYBM5M',
#    'id': '37i9dQZF1DXcBWIGoYBM5M',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706f000000020ba81215546ef8fd79aa92a7',
#      'width': None}],
#    'name': 'Today’s Top Hits',
#    'owner': {'display_name': 'Spotify',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#     'href': 'https://api.spotify.com/v1/users/spotify',
#     'id': 'spotify',
#     'type': 'user',
#     'uri': 'spotify:user:spotify'},
# ...

# %%
playlist_link = 'https://open.spotify.com/playlist/5ABHKGoOzxkaa28ttQV9sE' # Top 100 playslist link

# %%
playlist_URI = playlist_link.split('/')[-1] # Extract the URI from playslist URL

# %%
data = sp.playlist_tracks(playlist_URI) # Storing album information

# %%
data['items'] # All songs information
# Out:
# [{'added_at': '2024-02-15T21:57:53Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/jonathan.holgersson'},
#    'href': 'https://api.spotify.com/v1/users/jonathan.holgersson',
#    'id': 'jonathan.holgersson',
#    'type': 'user',
#    'uri': 'spotify:user:jonathan.holgersson'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
# ...

# %%
data['items'][0] # 1st song information
# Out:
# {'added_at': '2024-02-15T21:57:53Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/jonathan.holgersson'},
#   'href': 'https://api.spotify.com/v1/users/jonathan.holgersson',
#   'id': 'jonathan.holgersson',
#   'type': 'user',
#   'uri': 'spotify:user:jonathan.holgersson'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'preview_url': None,
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
# ...

# %%
len(data['items'])  # Total songs information availableb
# Out:
# 100

# %%
data['items'][0]['track']['album']['id'] # Extracting 1st song track album id
# Out:
# '4yP0hdKOZPNshxUOjY0cZj'

# %%
data['items'][0]['track']['album']['name'] # Extracting 1st song track album name
# Out:
# 'After Hours'

# %%
data['items'][0]['track']['album']['release_date'] # Extracting 1st song track album release_date
# Out:
# '2020-03-20'

# %%
data['items'][0]['track']['album']['total_tracks'] # Extracting 1st song track album total_tracks
# Out:
# 14

# %%
data['items'][0]['track']['album']['external_urls']['spotify'] # Extracting 1st song track album external_urls
# Out:
# 'https://open.spotify.com/album/4yP0hdKOZPNshxUOjY0cZj'

# %%
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_element = {'album_id':album_id, 'name':album_name, 'release_date':album_release_date,
                    'total_tracks':album_total_tracks, 'url':album_url}
    album_list.append(album_element)
print(album_list)  # getting the structures album related info for all 100 songs
# Out:
# [{'album_id': '4yP0hdKOZPNshxUOjY0cZj', 'name': 'After Hours', 'release_date': '2020-03-20', 'total_tracks': 14, 'url': 'https://open.spotify.com/album/4yP0hdKOZPNshxUOjY0cZj'}, {'album_id': '3T4tUhGYeRNVUGevb0wThu', 'name': '÷ (Deluxe)', 'release_date': '2017-03-03', 'total_tracks': 16, 'url': 'https://open.spotify.com/album/3T4tUhGYeRNVUGevb0wThu'}, {'album_id': '5658aM19fA3JVwTK6eQX70', 'name': 'Divinely Uninspired To A Hellish Extent', 'release_date': '2019-05-17', 'total_tracks': 12, 'url': 'https://open.spotify.com/album/5658aM19fA3JVwTK6eQX70'}, {'album_id': '35s58BRTGAEWztPo9WqCIs', 'name': 'Spider-Man: Into the Spider-Verse (Soundtrack From & Inspired by the Motion Picture)', 'release_date': '2018-12-14', 'total_tracks': 13, 'url': 'https://open.spotify.com/album/35s58BRTGAEWztPo9WqCIs'}, {'album_id': '09fggMHib4YkOtwQNXEBII', 'name': 'Starboy', 'release_date': '2016-11-25', 'total_tracks': 18, 'url': 'https://open.spotify.com/album/09fggMHib4YkOtwQNXEBII'}, {'album_id': '5r
# ...

# %%
data['items'][2]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4GNC7GD6oZMSxPGyXy4MNB'},
#   'href': 'https://api.spotify.com/v1/artists/4GNC7GD6oZMSxPGyXy4MNB',
#   'id': '4GNC7GD6oZMSxPGyXy4MNB',
#   'name': 'Lewis Capaldi',
#   'type': 'artist',
#   'uri': 'spotify:artist:4GNC7GD6oZMSxPGyXy4MNB'}]

# %%
artist_list = []
for row in data['items']:
    for key, value in row.items():
        if key == 'track':
            for artist in value['artists']:
                artist_dict = {'artist_id':artist['id'], 'artist_name':artist['name'], 'external_url':artist['href']}
                artist_list.append(artist_dict)
print(artist_list) # Getting structures artist list
# Out:
# [{'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ', 'artist_name': 'The Weeknd', 'external_url': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ'}, {'artist_id': '6eUKZXaKkcviH0Ku9w2n3V', 'artist_name': 'Ed Sheeran', 'external_url': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V'}, {'artist_id': '4GNC7GD6oZMSxPGyXy4MNB', 'artist_name': 'Lewis Capaldi', 'external_url': 'https://api.spotify.com/v1/artists/4GNC7GD6oZMSxPGyXy4MNB'}, {'artist_id': '246dkjvS1zLTtiykXe5h60', 'artist_name': 'Post Malone', 'external_url': 'https://api.spotify.com/v1/artists/246dkjvS1zLTtiykXe5h60'}, {'artist_id': '1zNqQNIdeOUZHb8zbZRFMX', 'artist_name': 'Swae Lee', 'external_url': 'https://api.spotify.com/v1/artists/1zNqQNIdeOUZHb8zbZRFMX'}, {'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ', 'artist_name': 'The Weeknd', 'external_url': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ'}, {'artist_id': '4tZwfgrHOc3mvqYlEYSvVi', 'artist_name': 'Daft Punk', 'external_url': 'https://api.spotify.com/v1/a
# ...

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id, 'song_name':song_name, 'song_duration':song_duration, 'song_url':song_url,
                   'song_popularity':song_popularity, 'song_added':song_added, 'album_id':album_id, 'artist_id':artist_id}
    song_list.append(song_element)
print(song_list)
# Out:
# [{'song_id': '0VjIjW4GlUZAMYd2vXMi3b', 'song_name': 'Blinding Lights', 'song_duration': 200040, 'song_url': 'https://open.spotify.com/track/0VjIjW4GlUZAMYd2vXMi3b', 'song_popularity': 90, 'song_added': '2024-02-15T21:57:53Z', 'album_id': '4yP0hdKOZPNshxUOjY0cZj', 'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ'}, {'song_id': '7qiZfU4dY1lWllzX7mPBI3', 'song_name': 'Shape of You', 'song_duration': 233712, 'song_url': 'https://open.spotify.com/track/7qiZfU4dY1lWllzX7mPBI3', 'song_popularity': 86, 'song_added': '2024-02-15T21:57:53Z', 'album_id': '3T4tUhGYeRNVUGevb0wThu', 'artist_id': '6eUKZXaKkcviH0Ku9w2n3V'}, {'song_id': '7qEHsqek33rTcFNT9PFqLf', 'song_name': 'Someone You Loved', 'song_duration': 182160, 'song_url': 'https://open.spotify.com/track/7qEHsqek33rTcFNT9PFqLf', 'song_popularity': 89, 'song_added': '2024-02-15T21:57:53Z', 'album_id': '5658aM19fA3JVwTK6eQX70', 'artist_id': '4GNC7GD6oZMSxPGyXy4MNB'}, {'song_id': '3KkXRkHbMCARz0aVfEt68P', 'song_name': 'Sunflower - Spider-Man: Into the Spid
# ...

# %%
album_df = pd.DataFrame.from_dict(album_list) # parsing list of dictionaries into pandas dataframe object

# %%
album_df.head(100)
# Out:
#                   album_id                                               name  \
# 0   4yP0hdKOZPNshxUOjY0cZj                                        After Hours
# 1   3T4tUhGYeRNVUGevb0wThu                                         ÷ (Deluxe)
# 2   5658aM19fA3JVwTK6eQX70            Divinely Uninspired To A Hellish Extent
# 3   35s58BRTGAEWztPo9WqCIs  Spider-Man: Into the Spider-Verse (Soundtrack ...
# 4   09fggMHib4YkOtwQNXEBII                                            Starboy
# ..                     ...                                                ...
# 95  1NAmidJlEaVgA3MpcPFYGq                                              Lover
# 96  5W9OT0a5iZlBr83a9WMKFY                    Synchronicity (Remastered 2003)
# 97  3eVgdnB6exMAVFE9PXT8EI                                        Told Before
# 98  3vLaOYCNCzngDf8QdBg2V1                                     Uptown Special
# 99  6hPkbAV3ZXpGZBGUvL6jVM                      Hybrid Theory (Bonus Edition)
#
#    release_date  total_tracks  \
# ...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      100 non-null    object
#  1   name          100 non-null    object
#  2   release_date  100 non-null    object
#  3   total_tracks  100 non-null    int64
#  4   url           100 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 4.0+ KB

# %%
album_df = album_df.drop_duplicates(subset=['album_id'])

# %%
artist_df = pd.DataFrame.from_dict(artist_list) # parsing list of dictionaries into pandas dataframe object

# %%
artist_df.head()
# Out:
#                 artist_id    artist_name  \
# 0  1Xyo4u8uXC1ZmMpatF05PJ     The Weeknd
# 1  6eUKZXaKkcviH0Ku9w2n3V     Ed Sheeran
# 2  4GNC7GD6oZMSxPGyXy4MNB  Lewis Capaldi
# 3  246dkjvS1zLTtiykXe5h60    Post Malone
# 4  1zNqQNIdeOUZHb8zbZRFMX       Swae Lee
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/1Xyo4u8uXC1...
# 1  https://api.spotify.com/v1/artists/6eUKZXaKkcv...
# 2  https://api.spotify.com/v1/artists/4GNC7GD6oZM...
# 3  https://api.spotify.com/v1/artists/246dkjvS1zL...
# 4  https://api.spotify.com/v1/artists/1zNqQNIdeOU...

# %%
artist_df = artist_df.drop_duplicates(subset=['artist_id'])

# %%
song_df = pd.DataFrame.from_dict(song_list) # parsing list of dictionaries into pandas dataframe object

# %%
song_df.head()
# Out:
#                   song_id                                      song_name  \
# 0  0VjIjW4GlUZAMYd2vXMi3b                                Blinding Lights
# 1  7qiZfU4dY1lWllzX7mPBI3                                   Shape of You
# 2  7qEHsqek33rTcFNT9PFqLf                              Someone You Loved
# 3  3KkXRkHbMCARz0aVfEt68P  Sunflower - Spider-Man: Into the Spider-Verse
# 4  5aAx2yezTd8zXrkmtKl66Z                                        Starboy
#
#    song_duration                                           song_url  \
# 0         200040  https://open.spotify.com/track/0VjIjW4GlUZAMYd...
# 1         233712  https://open.spotify.com/track/7qiZfU4dY1lWllz...
# 2         182160  https://open.spotify.com/track/7qEHsqek33rTcFN...
# 3         158040  https://open.spotify.com/track/3KkXRkHbMCARz0a...
# 4         230453  https://open.spotify.com/track/5aAx2yezTd8zXrk...
#
#    song_popularity            song_added                album_id  \
# ...

# %%
album_df.head()
# Out:
#                  album_id                                               name  \
# 0  4yP0hdKOZPNshxUOjY0cZj                                        After Hours
# 1  3T4tUhGYeRNVUGevb0wThu                                         ÷ (Deluxe)
# 2  5658aM19fA3JVwTK6eQX70            Divinely Uninspired To A Hellish Extent
# 3  35s58BRTGAEWztPo9WqCIs  Spider-Man: Into the Spider-Verse (Soundtrack ...
# 4  09fggMHib4YkOtwQNXEBII                                            Starboy
#
#   release_date  total_tracks  \
# 0   2020-03-20            14
# 1   2017-03-03            16
# 2   2019-05-17            12
# 3   2018-12-14            13
# 4   2016-11-25            18
#
#                                                  url
# 0  https://open.spotify.com/album/4yP0hdKOZPNshxU...
# 1  https://open.spotify.com/album/3T4tUhGYeRNVUGe...
# 2  https://open.spotify.com/album/5658aM19fA3JVwT...
# 3  https://open.spotify.com/album/35s58BRTGAEWztP...
# 4  https://open.spotify.com/album/09fggMHib4YkOtw...

# %%
artist_df.head()
# Out:
#                 artist_id    artist_name  \
# 0  1Xyo4u8uXC1ZmMpatF05PJ     The Weeknd
# 1  6eUKZXaKkcviH0Ku9w2n3V     Ed Sheeran
# 2  4GNC7GD6oZMSxPGyXy4MNB  Lewis Capaldi
# 3  246dkjvS1zLTtiykXe5h60    Post Malone
# 4  1zNqQNIdeOUZHb8zbZRFMX       Swae Lee
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/1Xyo4u8uXC1...
# 1  https://api.spotify.com/v1/artists/6eUKZXaKkcv...
# 2  https://api.spotify.com/v1/artists/4GNC7GD6oZM...
# 3  https://api.spotify.com/v1/artists/246dkjvS1zL...
# 4  https://api.spotify.com/v1/artists/1zNqQNIdeOU...

# %%
album_df.info() # release_date is in object data type
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 93 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      93 non-null     object
#  1   name          93 non-null     object
#  2   release_date  93 non-null     object
#  3   total_tracks  93 non-null     int64
#  4   url           93 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 4.4+ KB

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'], errors='coerce') # converting release_date in datetime type

# %%
album_df['release_date']
# Out:
# 0    2020-03-20
# 1    2017-03-03
# 2    2019-05-17
# 3    2018-12-14
# 4    2016-11-25
#         ...
# 95   2019-08-23
# 96   1983-06-17
# 97   2024-03-29
# 98   2015-01-12
# 99          NaT
# Name: release_date, Length: 93, dtype: datetime64[ns]

# %%
song_df['song_added'] = pd.to_datetime(song_df['song_added'])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   song_id          100 non-null    object
#  1   song_name        100 non-null    object
#  2   song_duration    100 non-null    int64
#  3   song_url         100 non-null    object
#  4   song_popularity  100 non-null    int64
#  5   song_added       100 non-null    datetime64[ns, UTC]
#  6   album_id         100 non-null    object
#  7   artist_id        100 non-null    object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 6.4+ KB
